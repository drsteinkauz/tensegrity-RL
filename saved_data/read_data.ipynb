# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
action_data = np.load('action_data.npy')
tendon_data = np.load('tendon_data.npy')
obs_tendon_data = np.load('observed_tendon_data.npy')
cap_posi_data = np.load('cap_posi_data.npy')
observed_cap_posi_data = np.load('observed_cap_posi_data.npy')
total_bar_contact_data = np.load('total_bar_contact_data.npy')
reward_forward_data = np.load('reward_forward_data.npy')
reward_ctrl_data = np.load('reward_ctrl_data.npy')
reward_angle_data = np.load('reward_angle_data.npy')

# %%
# action_subdata = action_data[:, :]
action_subdata = action_data[0:1500, 0]
plt.figure(figsize=(12, 8))  # 设置图形大小
plt.subplot(311)
plt.plot(action_subdata, marker='.', linestyle='-')  # 绘制折线图
plt.title('action subdata')  # 图表标题
plt.ylabel('Value')  # y轴标签
plt.grid()  # 显示网格

# tendon_subdata = tendon_data[:, 0:6]
tendon_subdata = tendon_data[0:1500, 0]
plt.subplot(312)
plt.plot(tendon_subdata, marker='.', linestyle='-')  # 绘制折线图
plt.title('tendon subdata')  # 图表标题
plt.ylabel('Value')  # y轴标签
plt.grid()  # 显示网格

obs_tendon_subdata = obs_tendon_data[0:1500, 0]
plt.subplot(313)
plt.plot(obs_tendon_subdata, marker='.', linestyle='-')  # 绘制折线图
plt.title('obs tendon subdata')  # 图表标题
plt.xlabel('Index')  # x轴标签
plt.ylabel('Value')  # y轴标签
plt.grid()  # 显示网格
plt.show()  # 显示图形



plt.figure(figsize=(12, 8))  # 设置图形大小
cap_posi_subdata_x = cap_posi_data[0:1500, 0]
plt.subplot(321)
plt.plot(cap_posi_subdata_x, marker='.', linestyle='-')  # 绘制折线图
plt.title('cap posi subdata')  # 图表标题
plt.ylabel('Value')  # y轴标签
plt.grid()  # 显示网格

obs_cap_posi_subdata_x = observed_cap_posi_data[0:1500, 0]
plt.subplot(322)
plt.plot(obs_cap_posi_subdata_x, marker='.', linestyle='-')  # 绘制折线图
plt.title('obs cap posi subdata')  # 图表标题
plt.grid()  # 显示网格

cap_posi_subdata_y = cap_posi_data[0:1500, 1]
plt.subplot(323)
plt.plot(cap_posi_subdata_y, marker='.', linestyle='-')  # 绘制折线图
plt.ylabel('Value')  # y轴标签
plt.grid()  # 显示网格

obs_cap_posi_subdata_y = observed_cap_posi_data[0:1500, 1]
plt.subplot(324)
plt.plot(obs_cap_posi_subdata_y, marker='.', linestyle='-')  # 绘制折线图
plt.grid()  # 显示网格

cap_posi_subdata_z = cap_posi_data[0:1500, 2]
plt.subplot(325)
plt.plot(cap_posi_subdata_z, marker='.', linestyle='-')  # 绘制折线图
plt.ylabel('Value')  # y轴标签
plt.xlabel('Index')  # x轴标签
plt.grid()  # 显示网格

obs_cap_posi_subdata_z = observed_cap_posi_data[0:1500, 2]
plt.subplot(326)
plt.plot(obs_cap_posi_subdata_z, marker='.', linestyle='-')  # 绘制折线图
plt.xlabel('Index')  # x轴标签
plt.grid()  # 显示网格
plt.show()  # 显示图形



tendon_subdata = tendon_data[0:1500, 0]
plt.figure(figsize=(12, 6))  # 设置图形大小
plt.subplot(321)
plt.plot(tendon_subdata, marker='.', linestyle='-')  # 绘制折线图
plt.title('tendon subdata')  # 图表标题
plt.ylabel('Value')  # y轴标签
plt.grid()  # 显示网格

tendon_subdata = tendon_data[0:1500, 1]
plt.subplot(322)
plt.plot(tendon_subdata, marker='.', linestyle='-')  # 绘制折线图
plt.title('tendon subdata')  # 图表标题
plt.ylabel('Value')  # y轴标签
plt.grid()  # 显示网格

tendon_subdata = tendon_data[0:1500, 2]
plt.subplot(323)
plt.plot(tendon_subdata, marker='.', linestyle='-')  # 绘制折线图
plt.ylabel('Value')  # y轴标签
plt.grid()  # 显示网格

tendon_subdata = tendon_data[0:1500, 3]
plt.subplot(324)
plt.plot(tendon_subdata, marker='.', linestyle='-')  # 绘制折线图
plt.ylabel('Value')  # y轴标签
plt.grid()  # 显示网格

tendon_subdata = tendon_data[0:1500, 4]
plt.subplot(325)
plt.plot(tendon_subdata, marker='.', linestyle='-')  # 绘制折线图
plt.xlabel('Index')  # x轴标签
plt.ylabel('Value')  # y轴标签
plt.grid()  # 显示网格

tendon_subdata = tendon_data[0:1500, 5]
plt.subplot(326)
plt.plot(tendon_subdata, marker='.', linestyle='-')  # 绘制折线图
plt.xlabel('Index')  # x轴标签
plt.ylabel('Value')  # y轴标签
plt.grid()  # 显示网格
plt.show()  # 显示图形



reward_forward_subdata = reward_forward_data
plt.figure(figsize=(12, 6))  # 设置图形大小
plt.plot(reward_forward_subdata, marker='.', linestyle='-')  # 绘制折线图
plt.title('reward forward subdata')  # 图表标题
plt.ylabel('Value')  # y轴标签
plt.grid()  # 显示网格
plt.show()  # 显示图形



reward_angle_subdata = reward_angle_data
plt.figure(figsize=(12, 6))  # 设置图形大小
plt.plot(reward_angle_subdata, marker='.', linestyle='-')  # 绘制折线图
plt.title('reward angle subdata')  # 图表标题
plt.ylabel('Value')  # y轴标签
plt.grid()  # 显示网格
plt.show()  # 显示图形



reward_ctrl_subdata = reward_ctrl_data
plt.figure(figsize=(12, 6))  # 设置图形大小
plt.plot(reward_ctrl_subdata, marker='.', linestyle='-')  # 绘制折线图
plt.title('reward ctrl subdata')  # 图表标题
plt.ylabel('Value')  # y轴标签
plt.grid()  # 显示网格
plt.show()  # 显示图形
