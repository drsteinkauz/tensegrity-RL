# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
action_data = np.load('action_data.npy')
tendon_data = np.load('tendon_data.npy')
obs_tendon_data = np.load('observed_tendon_data.npy')
cap_posi_data = np.load('cap_posi_data.npy')
observed_cap_posi_data = np.load('observed_cap_posi_data.npy')
total_bar_contact_data = np.load('total_bar_contact_data.npy')
reward_forward_data = np.load('reward_forward_data.npy')
reward_ctrl_data = np.load('reward_ctrl_data.npy')
tracking_fwd_rew_data = np.load('tracking_fwd_rew_data.npy')
tracking_ang_rew_data = np.load('tracking_ang_rew_data.npy')
tracking_waypt_rew_data = np.load('tracking_waypt_rew_data.npy')
waypt_data = np.load('waypt_data.npy')
x_pos_data = np.load('x_pos_data.npy')
y_pos_data = np.load('y_pos_data.npy')
new_psi_rbt_tgt_data = np.load('new_psi_rbt_tgt_data.npy')

# %%
# action_subdata = action_data[:, :]
action_subdata = action_data[0:1500, 0]
plt.figure(figsize=(12, 8))
plt.subplot(311)
plt.plot(action_subdata, marker='.', linestyle='-')
plt.title('action subdata')
plt.ylabel('Value')
plt.grid()

# tendon_subdata = tendon_data[:, 0:6]
tendon_subdata = tendon_data[0:1500, 0]
plt.subplot(312)
plt.plot(tendon_subdata, marker='.', linestyle='-')
plt.title('tendon subdata')
plt.ylabel('Value')
plt.grid()

obs_tendon_subdata = obs_tendon_data[0:1500, 0]
plt.subplot(313)
plt.plot(obs_tendon_subdata, marker='.', linestyle='-')
plt.title('obs tendon subdata')
plt.xlabel('Index')
plt.ylabel('Value')
plt.grid()
plt.show()



plt.figure(figsize=(12, 8))
cap_posi_subdata_x = cap_posi_data[0:1500, 0]
plt.subplot(321)
plt.plot(cap_posi_subdata_x, marker='.', linestyle='-')
plt.title('cap posi subdata')
plt.ylabel('Value')
plt.grid()

obs_cap_posi_subdata_x = observed_cap_posi_data[0:1500, 0]
plt.subplot(322)
plt.plot(obs_cap_posi_subdata_x, marker='.', linestyle='-')
plt.title('obs cap posi subdata')
plt.grid()

cap_posi_subdata_y = cap_posi_data[0:1500, 1]
plt.subplot(323)
plt.plot(cap_posi_subdata_y, marker='.', linestyle='-')
plt.ylabel('Value')
plt.grid()

obs_cap_posi_subdata_y = observed_cap_posi_data[0:1500, 1]
plt.subplot(324)
plt.plot(obs_cap_posi_subdata_y, marker='.', linestyle='-')
plt.grid()

cap_posi_subdata_z = cap_posi_data[0:1500, 2]
plt.subplot(325)
plt.plot(cap_posi_subdata_z, marker='.', linestyle='-')
plt.ylabel('Value')
plt.xlabel('Index')
plt.grid()

obs_cap_posi_subdata_z = observed_cap_posi_data[0:1500, 2]
plt.subplot(326)
plt.plot(obs_cap_posi_subdata_z, marker='.', linestyle='-')
plt.xlabel('Index')
plt.grid()
plt.show()



tendon_subdata = tendon_data[0:1500, 0]
plt.figure(figsize=(12, 6))
plt.subplot(321)
plt.plot(tendon_subdata, marker='.', linestyle='-')
plt.title('tendon subdata')
plt.ylabel('Value')
plt.grid()

tendon_subdata = tendon_data[0:1500, 1]
plt.subplot(322)
plt.plot(tendon_subdata, marker='.', linestyle='-')
plt.title('tendon subdata')
plt.ylabel('Value')
plt.grid()

tendon_subdata = tendon_data[0:1500, 2]
plt.subplot(323)
plt.plot(tendon_subdata, marker='.', linestyle='-')
plt.ylabel('Value')
plt.grid()

tendon_subdata = tendon_data[0:1500, 3]
plt.subplot(324)
plt.plot(tendon_subdata, marker='.', linestyle='-')
plt.ylabel('Value')
plt.grid()

tendon_subdata = tendon_data[0:1500, 4]
plt.subplot(325)
plt.plot(tendon_subdata, marker='.', linestyle='-')
plt.xlabel('Index')
plt.ylabel('Value')
plt.grid()

tendon_subdata = tendon_data[0:1500, 5]
plt.subplot(326)
plt.plot(tendon_subdata, marker='.', linestyle='-')
plt.xlabel('Index')
plt.ylabel('Value')
plt.grid()
plt.show()



plt.figure(figsize=(12, 10))
tracking_fwd_rew_subdata = tracking_fwd_rew_data[0:1500]
plt.subplot(411)
plt.plot(tracking_fwd_rew_subdata, marker='.', linestyle='-')
plt.ylabel('tracking forward reward')
plt.grid()


tracking_ang_rew_subdata = tracking_ang_rew_data[0:1500]
plt.subplot(412)
plt.plot(tracking_ang_rew_subdata, marker='.', linestyle='-')
plt.ylabel('tracking angle reward')
plt.grid()

tracking_waypt_rew_subdata = tracking_waypt_rew_data[0:1500]
plt.subplot(413)
plt.plot(tracking_waypt_rew_subdata, marker='.', linestyle='-')
plt.ylabel('tracking waypoint reward')
plt.grid()

tracking_total_rew_subdata = tracking_fwd_rew_subdata + tracking_ang_rew_subdata + tracking_waypt_rew_subdata
plt.subplot(414)
plt.plot(tracking_total_rew_subdata, marker='.', linestyle='-')
plt.ylabel('tracking total reward')
plt.grid()
plt.show()

# print('sum of tracking total reward: ', np.sum(tracking_total_rew_subdata))
# print('sum of tracking forward reward: ', np.sum(tracking_fwd_rew_subdata))
# print('sum of tracking angle reward: ', np.sum(tracking_ang_rew_subdata))
# print('sum of tracking waypoint reward: ', np.sum(tracking_waypt_rew_subdata))



plt.figure(figsize=(12, 8))
reward_forward_subdata = reward_forward_data
plt.subplot(211)
plt.plot(reward_forward_subdata, marker='.', linestyle='-')
plt.ylabel('reward forward subdata')
plt.grid()

reward_ctrl_subdata = reward_ctrl_data
plt.subplot(212)
plt.plot(reward_ctrl_subdata, marker='.', linestyle='-')
plt.ylabel('reward ctrl subdata')
plt.grid()
plt.show()

print('sum of reward forward: ', np.sum(reward_forward_subdata))
print('sum of reward ctrl: ', np.sum(reward_ctrl_subdata))



x_pos_subdata = x_pos_data
y_pos_subdata = y_pos_data
plt.figure(figsize=(8, 8))
plt.plot(x_pos_subdata, y_pos_subdata, marker='.', linestyle='-')
plt.plot(waypt_data[:, 0], waypt_data[:, 1], marker='o', linestyle='None')
plt.title('x-y position')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.gca().set_aspect('equal', adjustable='box')
plt.show()



x_vel_data = np.diff(x_pos_data, axis=0)
y_vel_data = np.diff(y_pos_data, axis=0)
x_vel_data /= 0.05
y_vel_data /= 0.05
plt.figure(figsize=(8, 8))
plt.subplot(211)
plt.plot(x_vel_data, marker='.', linestyle='-')
plt.ylabel('x velocity')
plt.grid()

plt.subplot(212)
plt.plot(y_vel_data, marker='.', linestyle='-')
plt.ylabel('y velocity')
plt.grid()
plt.show()



plt.figure(figsize=(8, 4))
plt.plot(new_psi_rbt_tgt_data, marker='.', linestyle='-')
plt.ylabel('psi robot-target')
plt.grid()
plt.show()
